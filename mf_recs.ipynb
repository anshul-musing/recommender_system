# %%
import pandas as pd
import numpy as np
from mf.factorize import Factorizer

# %%
fact = Factorizer()

# %%
fact.fit(method='svd')
fact.predict(payload={'user':'U1'})
# Out:
# ingesting ...
# preprocessing ...
# fitting matrix factorization ...
# ({'P1': 0.30931897149421017,
#   'P2': -0.17592486332394022,
#   'P3': 0.9647799513486296,
#   'P4': -0.12562746256709106,
#   'P5': 0.801201572428396,
#   'P6': -0.8068010825435064,
#   'P7': -0.6508811410538912,
#   'P8': 0.9647799513486295,
#   'P9': 1.1283583302688625,
#   'P10': 0.3462502165327704,
#   'P11': 0.3493288151628595,
#   'P12': 0.7888550880246887,
#   'P13': 0.040118051841210874,
#   'P14': -0.49748211104929657,
#   'P15': -0.31847864909526746,
#   'P16': -0.8113809213440352,
#   'P17': 0.49290227224876776,
#   'P18': -0.8144595199741238,
#   'P19': -0.12104762376656211,
#   'P20': 0.9647799513486295,
#   'P21': 0.6508811410538912,
#   'P22': -0.02000492183432465,
#   'P23': -0.1302073013676195,
#   'P24': 0.19809692064633347,
#   'P25': 0.0045798388005287224,
#   'P26': 0.952433466944922,
#   'P27': 0.7821081137360917,
#   'P28': -0.45278422040755717,
#   'P29': 0.30931897149421006,
# ...

# %%
fact.fit(method='nmf')
fact.predict(payload={'user':'U1'})
# Out:
# ingesting ...
# preprocessing ...
# fitting matrix factorization ...
# ({'P1': 0.330572245093665,
#   'P2': -0.05311122121418835,
#   'P3': 1.0721857197978286,
#   'P4': 0.09406024253785626,
#   'P5': 1.0721857197978286,
#   'P6': -0.15680640611469077,
#   'P7': -0.3131283522638811,
#   'P8': 1.0721857197978286,
#   'P9': 1.0687582710015173,
#   'P10': 0.5362012064340558,
#   'P11': 1.021097649330542,
#   'P12': 1.0193864041680623,
#   'P13': 0.62826492599122,
#   'P14': -0.30944693039908344,
#   'P15': 0.22750807788196103,
#   'P16': -0.3553261938759745,
#   'P17': 0.5618503021115793,
#   'P18': -0.3182089315826888,
#   'P19': 0.41034738944931515,
#   'P20': 1.0721857197978286,
#   'P21': 1.0190744985836402,
#   'P22': -0.18911840135023017,
#   'P23': 0.3009951932988322,
#   'P24': 1.0721857197978286,
#   'P25': 0.3837535813165106,
#   'P26': 1.0193864041680623,
#   'P27': 0.5262357913661457,
#   'P28': 0.10605776210557703,
#   'P29': 0.330572245093665,
# ...

# %%
fact.fit(method='lda')
fact.predict(payload={'user':'U1'})
# Out:
# ingesting ...
# preprocessing ...
# fitting matrix factorization ...
# ({'P1': 13.706422768299545,
#   'P2': -0.8394626291435239,
#   'P3': 21.642732230879098,
#   'P4': -5.576955466538999,
#   'P5': 22.048233636055883,
#   'P6': -18.166654530750098,
#   'P7': -10.883684548392788,
#   'P8': 21.642732230879098,
#   'P9': 7.526533837388287,
#   'P10': 19.58631320667995,
#   'P11': 22.324254271299466,
#   'P12': 20.881565610600642,
#   'P13': 16.74575557184272,
#   'P14': -0.8394596834548025,
#   'P15': 6.267308547692707,
#   'P16': -1.5150259162313031,
#   'P17': -6.045150535895473,
#   'P18': -10.54219384536551,
#   'P19': -11.822446054679133,
#   'P20': 21.642732230879098,
#   'P21': 21.809411580337215,
#   'P22': 5.5997907760081915,
#   'P23': 1.3243108735217675,
#   'P24': 23.781364296682277,
#   'P25': -6.231351091955245,
#   'P26': 20.476064205423857,
#   'P27': -8.563172117685152,
#   'P28': 8.893629558413727,
#   'P29': 13.706422768299545,
#   'P30': 7.7264943694115935},
# ...

# %%
fact.fit(method='als')
fact.predict(payload={'user':'U1'})
# Out:
# ingesting ...
# preprocessing ...
# fitting matrix factorization ...
# Iteration 0 error: 2559.194708538672
# Iteration 100 error: 279.11404405769065
# Iteration 200 error: 236.22316162633098
# Iteration 300 error: 229.037768029534
# Iteration 400 error: 224.750378309774
# Iteration 500 error: 219.84087875155984
# Iteration 600 error: 213.90557986794704
# Iteration 700 error: 208.42142511291536
# Iteration 800 error: 204.6973576849419
# Iteration 900 error: 202.45956940653943
# Iteration 1000 error: 201.06198488843535
# Iteration 1100 error: 200.12017030961897
# Iteration 1200 error: 199.44443499034074
# Iteration 1300 error: 198.9370163930107
# Iteration 1400 error: 198.54309527873923
# Iteration 1500 error: 198.22950742294893
# Iteration 1600 error: 197.97491906259663
# Iteration 1700 error: 197.7649175829863
# Iteration 1800 error: 197.5893778843006
# Iteration 1900 error: 197.44096101168506
# Iteration 2000 error: 197.31421201652668
# Iteration 2100 error: 197.2049925621404
# ...

# %%
fact.fit(method='xmf')
fact.predict(payload={'user':'U1'})
# Out:
# ingesting ...
# preprocessing ...
# fitting matrix factorization ...
# ({'P1': 1.0002284082715691,
#   'P2': 0.36223092514514976,
#   'P3': 0.9995706597195592,
#   'P4': 0.24256612693608492,
#   'P5': 0.9999563318480404,
#   'P6': -0.9977450088891688,
#   'P7': -0.9976967768502278,
#   'P8': 0.9995706597195622,
#   'P9': 0.9990484057535388,
#   'P10': 0.950299404758681,
#   'P11': 0.9979795005020562,
#   'P12': 1.0016012191314323,
#   'P13': 0.9997475060335369,
#   'P14': 0.6493000044160187,
#   'P15': 0.9977103015125731,
#   'P16': -0.05006133578716537,
#   'P17': 0.9994538603906935,
#   'P18': -0.994199817765625,
#   'P19': -0.9970752521934222,
#   'P20': 0.9995706597195602,
#   'P21': 0.998965021750138,
#   'P22': 1.122271247883721,
#   'P23': 0.9882717257789636,
#   'P24': 0.9995053806264507,
#   'P25': -0.998740003282556,
#   'P26': 0.9987133599752401,
#   'P27': 0.9949921410681267,
#   'P28': 1.7433721975264473,
#   'P29': 1.0002284082715691,
#   'P30': 3.8019821992868783},
# ...
